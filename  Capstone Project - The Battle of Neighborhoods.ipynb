# %% [markdown]
# # Capstone Project - The Battle of the Neighborhoods (Week 2)
# ### Applied Data Science Capstone by IBM/Coursera

# %% [markdown]
# ## Table of contents
# * [Introduction: Business Problem](#introduction)
# * [Data](#data)
# * [Methodology](#methodology)
# * [Results and Discussion](#results)
# * [Conclusion](#conclusion)

# %% [markdown]
# ## Introduction: Business Problem <a name="introduction"></a>

# %% [markdown]
# In this project we will try to find an optimal location for a restaurant. Specifically, this report will be targeted to stakeholders who has a successful restaurant in one city (New York City here) interested in opening a **chain restaurant** (Chinese Restaurant here) in a new city (Los Angeles here).
#
# With the development of economy, more and more businessmen want to open chain stores, but if choosing the wrong place, they may face bankrupt. Thus, if we can find an optimal location in the new city for them to open the new store, then the risk will be lower.
#
# Since the stakeholder already has a popular restaurant in one place (New York City here), we will use our data science powers to detect the neighborhoods of successful restaurant and find a similar place in another city (Los Angeles here) so that the new opened restaurant will have similar environment with in the old place (New York City) which will lower the risk of investment.

# %% [markdown]
# ## Data <a name="data"></a>

# %% [markdown]
# We will use Foursquare location data to solve the problem or execute the idea. With the Foursquare location data, we can get the neighborhoods of the restaurant that we are focusing. Within these neighborhoods, we may find the different categories and their frequency. Then we may find a place in Los Angeles which has similar neighborhoods.

# %% [markdown]
# ### Import several libraries we need

# %%
import numpy as np # library to handle data in a vectorized manner

import pandas as pd # library for data analsysis

import json # library to handle JSON files

# !pip install geopy
from geopy.geocoders import Nominatim # convert an address into latitude and longitude values

import requests # library to handle requests
from pandas import json_normalize # tranform JSON file into a pandas dataframe

# Matplotlib and associated plotting modules
import matplotlib.cm as cm
import matplotlib.colors as colors

# import k-means from clustering stage
from sklearn.cluster import KMeans

! pip install folium==0.5.0
import folium # map rendering library

print('Libraries imported.')
# Out:
# Requirement already satisfied: geopy in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (2.0.0)
# Requirement already satisfied: geographiclib<2,>=1.49 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from geopy) (1.50)
# Collecting folium==0.5.0
#   Downloading folium-0.5.0.tar.gz (79 kB)
#      |████████████████████████████████| 79 kB 7.8 MB/s  eta 0:00:01
# Collecting branca
#   Downloading branca-0.4.1-py3-none-any.whl (24 kB)
# Requirement already satisfied: jinja2 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from folium==0.5.0) (2.11.2)
# Requirement already satisfied: requests in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from folium==0.5.0) (2.24.0)
# Requirement already satisfied: six in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from folium==0.5.0) (1.15.0)
# Requirement already satisfied: MarkupSafe>=0.23 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from jinja2->folium==0.5.0) (1.1.1)
# Requirement already satisfied: chardet<4,>=3.0.2 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from requests->folium==0.5.0) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from requests->folium==0.5.0) (2020.6.20)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from requests->folium==0.5.0) (1.25.9)
# Requirement already satisfied: idna<3,>=2.5 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from requests->folium==0.5.0) (2.9)
# Building wheels for collected packages: folium
#   Building wheel for folium (setup.py) ... done
#   Created wheel for folium: filename=folium-0.5.0-py3-none-any.whl size=76240 sha256=578371a31a0bf8823b9c6f84eca70f3ff26312bb4f996220c4d17a2d5e76c1f2
#   Stored in directory: /tmp/wsuser/.cache/pip/wheels/b2/2f/2c/109e446b990d663ea5ce9b078b5e7c1a9c45cca91f377080f8
# Successfully built folium
# Installing collected packages: branca, folium
# Successfully installed branca-0.4.1 folium-0.5.0
# Libraries imported.

# %% [markdown]
# ## Find a specific restaurant to focus

# %% [markdown]
# In order to do our analysis, we need to find a specific restaurant to focus. This restaurant should be successful in New York, but there is no chain store in Los Angeles. More specificlly, we want to find a Chinese restaurant that satisfies the conditions .

# %% [markdown]
# #### Let's find the latitude and longtitude of the New York City first.

# %%
address = 'New York City, NY'

geolocator = Nominatim(user_agent="ny_explorer")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geograpical coordinate of New York City are {}, {}.'.format(latitude, longitude))
# Out:
# The geograpical coordinate of New York City are 40.7127281, -74.0060152.

# %% [markdown]
# #### Define Foursquare Credentials and Version

# %%
CLIENT_ID = 'OJZQTCIXLU2304V4LWI2CGHET4XQZXVZ2S5UODMOTQISJYBE' # your Foursquare ID
CLIENT_SECRET = 'GLZOQ02EVR3O5IQ0USP4NSQ4ICTKGD1E34GKWM5NLXKQUYHD' # your Foursquare Secret
VERSION = '20200715'
LIMIT = 50
print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: OJZQTCIXLU2304V4LWI2CGHET4XQZXVZ2S5UODMOTQISJYBE
# CLIENT_SECRET:GLZOQ02EVR3O5IQ0USP4NSQ4ICTKGD1E34GKWM5NLXKQUYHD

# %% [markdown]
# #### Find 50 Chinese Restaurants around center of New York City

# %%
search_query = 'Chinese Restaurant'
radius = 1000
print(search_query + ' .... OK!')
# Out:
# Chinese Restaurant .... OK!

# %%
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=QQ00XWC5002MSZSV5PYXPSA5RYNZ4AK4ZKR1OPKDT1OVDHJI&client_secret=FNA2DAHWEZ5Z3MV4BBUMEBDYSO4G2X21DGMFZM1LXIRIYEAF&ll=40.7127281,-74.0060152&v=20200715&query=Chinese Restaurant&radius=1000&limit=50'

# %%
results = requests.get(url).json()
# Out:
# {'meta': {'code': 200, 'requestId': '5fc29ecc432e02660c9094b4'},
#  'response': {'venues': [{'id': '58aa398b14fb41097a0cf923',
#     'name': 'Great Fortune Chinese Restaurant 聚旺茶餐廳',
#     'location': {'address': '5 Catherine St',
#      'crossStreet': 'btwn E Broadway & Chatham Sq',
#      'lat': 40.713875,
#      'lng': -73.99728,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.713875,
#        'lng': -73.99728}],
#      'distance': 748,
#      'postalCode': '10038',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['5 Catherine St (btwn E Broadway & Chatham Sq)',
#       'New York, NY 10038',
#       'United States']},
#     'categories': [{'id': '52af3a7c3cf9994f4e043bed',
#       'name': 'Cantonese Restaurant',
#       'pluralName': 'Cantonese Restaurants',
#       'shortName': 'Cantonese',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1606590156',
#     'hasPerk': False},
#    {'id': '4e4463cf52b18fcc799a9761',
#     'name': '88 Reach House chinese restaurant',
#     'location': {'address': '88 Division St',
#      'crossStreet': 'Eldrige street',
#      'lat': 40.714468,
#      'lng': -73.993727,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.714468,
#        'lng': -73.993727}],
#      'distance': 1054,
#      'postalCode': '10002',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['88 Division St (Eldrige street)',
#       'New York, NY 10002',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d145941735',
#       'name': 'Chinese Restaurant',
#       'pluralName': 'Chinese Restaurants',
#       'shortName': 'Chinese',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1606590156',
#     'hasPerk': False},
#    {'id': '581299bb38fa2e54303f6891',
#     'name': 'Taste Chinese Restaurant',
#     'location': {'address': '178 Church St',
#      'lat': 40.7156902,
#      'lng': -74.0076053,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.7156902,
#        'lng': -74.0076053}],
#      'distance': 355,
#      'postalCode': '10013',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['178 Church St',
#       'New York, NY 10013',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d145941735',
#       'name': 'Chinese Restaurant',
#       'pluralName': 'Chinese Restaurants',
#       'shortName': 'Chinese',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'delivery': {'id': '322507',
#      'url': 'https://www.seamless.com/menu/taste-chinese-restaurant-178-church-st-new-york/322507?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=322507',
#      'provider': {'name': 'seamless',
#       'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#        'sizes': [40, 50],
#        'name': '/delivery_provider_seamless_20180129.png'}}},
#     'referralId': 'v-1606590156',
#     'hasPerk': False},
#    {'id': '4b54fcddf964a520bfd627e3',
#     'name': 'Food King Chinese Restaurant',
#     'location': {'address': '56 Market St',
#      'crossStreet': 'Monroe',
#      'lat': 40.711605739394905,
#      'lng': -73.99418615450294,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.711605739394905,
#        'lng': -73.99418615450294},
#       {'label': 'entrance', 'lat': 40.711721, 'lng': -73.994162}],
#      'distance': 1005,
#      'postalCode': '10002',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['56 Market St (Monroe)',
#       'New York, NY 10002',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d145941735',
#       'name': 'Chinese Restaurant',
#       'pluralName': 'Chinese Restaurants',
#       'shortName': 'Chinese',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1606590156',
#     'hasPerk': False},
#    {'id': '4e4e4c7abd4101d0d7a72532',
#     'name': 'Dragon Gate Chinese Restaurant',
#     'location': {'address': '92 Elizabeth St',
#      'lat': 40.718358,
#      'lng': -73.995632,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.718358,
#        'lng': -73.995632}],
#      'distance': 1077,
#      'postalCode': '10013',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['92 Elizabeth St',
#       'New York, NY 10013',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d145941735',
#       'name': 'Chinese Restaurant',
#       'pluralName': 'Chinese Restaurants',
#       'shortName': 'Chinese',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1606590156',
#     'hasPerk': False},
#    {'id': '4f320f6d19833175d60c8d97',
#     'name': 'Downtown Chinese Restaurant',
#     'location': {'address': '135 John St',
#      'lat': 40.70713424682617,
#      'lng': -74.00494384765625,
#      'labeledLatLngs': [{'label': 'entrance',
#        'lat': 40.707098,
#        'lng': -74.005032},
#       {'label': 'display',
#        'lat': 40.70713424682617,
#        'lng': -74.00494384765625}],
#      'distance': 629,
#      'postalCode': '10038',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['135 John St',
#       'New York, NY 10038',
#       'United States']},
#     'categories': [{'id': '4d4b7105d754a06374d81259',
#       'name': 'Food',
#       'pluralName': 'Food',
#       'shortName': 'Food',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1606590156',
#     'hasPerk': False},
#    {'id': '5012c0fde4b0748a78b0c886',
#     'name': "Ann's Chinese Restaurant",
#     'location': {'address': '1 E Broadway #2FL',
#      'lat': 40.71315383911133,
#      'lng': -73.99795532226562,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.71315383911133,
#        'lng': -73.99795532226562}],
#      'distance': 681,
#      'postalCode': '10038',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['1 E Broadway #2FL',
#       'New York, NY 10038',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d142941735',
#       'name': 'Asian Restaurant',
#       'pluralName': 'Asian Restaurants',
#       'shortName': 'Asian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1606590156',
#     'hasPerk': False},
#    {'id': '50b043dbe4b0be4ddec7cf6a',
#     'name': 'Malasia-Thai-Chinese Restaurant',
#     'location': {'lat': 40.717035,
#      'lng': -73.999719,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.717035,
#        'lng': -73.999719}],
#      'distance': 715,
#      'postalCode': '10013',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['New York, NY 10013', 'United States']},
#     'categories': [{'id': '4bf58dd8d48988d142941735',
#       'name': 'Asian Restaurant',
#       'pluralName': 'Asian Restaurants',
#       'shortName': 'Asian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1606590156',
#     'hasPerk': False},
#    {'id': '4e4e4c65bd4101d0d7a723cb',
#     'name': 'Marco Polo Chinese Restaurant',
#     'location': {'address': '94 Baxter St',
#      'lat': 40.71692037258939,
#      'lng': -73.99941905942059,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.71692037258939,
#        'lng': -73.99941905942059}],
#      'distance': 726,
#      'postalCode': '10013',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['94 Baxter St',
#       'New York, NY 10013',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d145941735',
#       'name': 'Chinese Restaurant',
#       'pluralName': 'Chinese Restaurants',
#       'shortName': 'Chinese',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1606590156',
#     'hasPerk': False},
#    {'id': '58913f12288b6a0e789bb237',
#     'name': 'Fu Zhou An Ping Chinese Restaurant',
#     'location': {'address': '20 Henry St',
#      'lat': 40.71272277832031,
#      'lng': -73.99687957763672,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.71272277832031,
#        'lng': -73.99687957763672}],
#      'distance': 770,
#      'postalCode': '10002',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['20 Henry St',
#       'New York, NY 10002',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d142941735',
#       'name': 'Asian Restaurant',
#       'pluralName': 'Asian Restaurants',
#       'shortName': 'Asian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1606590156',
#     'hasPerk': False},
#    {'id': '4d83993c81fdb1f7cf87eabf',
#     'name': 'Canal Best Chinese Restaurant',
#     'location': {'address': '266 Canal St',
#      'lat': 40.718789938826056,
#      'lng': -74.00105530067245,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.718789938826056,
#        'lng': -74.00105530067245}],
#      'distance': 794,
#      'postalCode': '10013',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['266 Canal St',
#       'New York, NY 10013',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d145941735',
#       'name': 'Chinese Restaurant',
#       'pluralName': 'Chinese Restaurants',
#       'shortName': 'Chinese',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1606590156',
#     'hasPerk': False},
#    {'id': '55f348b7498e60a6896b0144',
#     'name': 'Wenger Chinese Restaurant',
#     'location': {'address': '103 Washington Street, 2/F',
#      'lat': 40.7083625793457,
#      'lng': -74.01404571533203,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.7083625793457,
#        'lng': -74.01404571533203}],
#      'distance': 833,
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['103 Washington Street, 2/F',
#       'New York, NY',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d145941735',
#       'name': 'Chinese Restaurant',
#       'pluralName': 'Chinese Restaurants',
#       'shortName': 'Chinese',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1606590156',
#     'hasPerk': False},
#    {'id': '4f3290ad19836c91c7e431ae',
#     'name': 'P and C Garden Chinese Restaurant',
#     'location': {'address': '44 Trinity Pl',
#      'lat': 40.7075309753418,
#      'lng': -74.0133056640625,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.7075309753418,
#        'lng': -74.0133056640625}],
#      'distance': 844,
#      'postalCode': '10006',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['44 Trinity Pl',
#       'New York, NY 10006',
#       'United States']},
#     'categories': [{'id': '4d4b7105d754a06374d81259',
#       'name': 'Food',
#       'pluralName': 'Food',
#       'shortName': 'Food',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1606590156',
#     'hasPerk': False},
#    {'id': '4fce736ae4b0409de3eb3b37',
#     'name': 'New Hao Ke Chinese Restaurant',
#     'location': {'address': '115 Madison St',
#      'lat': 40.712379455566406,
#      'lng': -73.99468994140625,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.712379455566406,
#        'lng': -73.99468994140625}],
#      'distance': 956,
#      'postalCode': '10002',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['115 Madison St',
#       'New York, NY 10002',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d145941735',
#       'name': 'Chinese Restaurant',
#       'pluralName': 'Chinese Restaurants',
#       'shortName': 'Chinese',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1606590156',
#     'hasPerk': False},
#    {'id': '5744a433498eb4d23a3e7ede',
#     'name': 'Pearl Chinese Restaurant',
#     'location': {'address': '81 Pearl St',
#      'lat': 40.70412826538086,
#      'lng': -74.01033782958984,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.70412826538086,
#        'lng': -74.01033782958984}],
#      'distance': 1024,
#      'postalCode': '10004',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['81 Pearl St',
#       'New York, NY 10004',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1c4941735',
#       'name': 'Restaurant',
#       'pluralName': 'Restaurants',
#       'shortName': 'Restaurant',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1606590156',
#     'hasPerk': False},
#    {'id': '4b88199af964a520e6df31e3',
#     'name': 'Win Won Restaurant',
#     'location': {'address': '10 Liberty Pl',
#      'crossStreet': 'Maiden Lane',
#      'lat': 40.709193,
#      'lng': -74.009344,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.709193,
#        'lng': -74.009344},
#       {'label': 'entrance', 'lat': 40.709177, 'lng': -74.009278}],
#      'distance': 483,
#      'postalCode': '10038',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['10 Liberty Pl (Maiden Lane)',
#       'New York, NY 10038',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d145941735',
#       'name': 'Chinese Restaurant',
#       'pluralName': 'Chinese Restaurants',
#       'shortName': 'Chinese',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1606590156',
#     'hasPerk': False},
#    {'id': '4ce56fbd5bf68cfa65f23c17',
#     'name': 'Number One Chinese',
#     'location': {'address': '10 S William St',
#      'lat': 40.704573575379875,
#      'lng': -74.01040987598235,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.704573575379875,
#        'lng': -74.01040987598235},
#       {'label': 'entrance', 'lat': 40.704726, 'lng': -74.010482}],
#      'distance': 980,
#      'postalCode': '10004',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['10 S William St',
#       'New York, NY 10004',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d145941735',
#       'name': 'Chinese Restaurant',
#       'pluralName': 'Chinese Restaurants',
#       'shortName': 'Chinese',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1606590156',
#     'hasPerk': False},
#    {'id': '3fd66200f964a520d5e31ee3',
#     'name': 'Jing Fong Restaurant 金豐大酒樓',
#     'location': {'address': '20 Elizabeth St',
#      'crossStreet': 'btwn Bayard & Canal St',
#      'lat': 40.7158812029412,
#      'lng': -73.99720861552515,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.7158812029412,
#        'lng': -73.99720861552515}],
#      'distance': 821,
#      'postalCode': '10013',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['20 Elizabeth St (btwn Bayard & Canal St)',
#       'New York, NY 10013',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1f5931735',
#       'name': 'Dim Sum Restaurant',
#       'pluralName': 'Dim Sum Restaurants',
#       'shortName': 'Dim Sum',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/dimsum_',
#        'suffix': '.png'},
#       'primary': True}],
#     'delivery': {'id': '296411',
#      'url': 'https://www.seamless.com/menu/jing-fong-restaurant-20-elizabeth-st-new-york/296411?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=296411',
#      'provider': {'name': 'seamless',
#       'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#        'sizes': [40, 50],
#        'name': '/delivery_provider_seamless_20180129.png'}}},
#     'venuePage': {'id': '89860853'},
#     'referralId': 'v-1606590156',
#     'hasPerk': False},
#    {'id': '4bac00a1f964a52025dd3ae3',
#     'name': 'Museum of Chinese in America (MOCA)',
#     'location': {'address': '215 Centre St',
#      'crossStreet': 'btwn Howard & Grand St',
#      'lat': 40.71936148321417,
#      'lng': -73.99908632040024,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.71936148321417,
#        'lng': -73.99908632040024}],
#      'distance': 941,
#      'postalCode': '10013',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['215 Centre St (btwn Howard & Grand St)',
#       'New York, NY 10013',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d190941735',
#       'name': 'History Museum',
#       'pluralName': 'History Museums',
#       'shortName': 'History Museum',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/museum_history_',
#        'suffix': '.png'},
#       'primary': True}],
#     'venuePage': {'id': '58596016'},
#     'referralId': 'v-1606590156',
#     'hasPerk': False},
#    {'id': '49f125dcf964a52091691fe3',
#     'name': "O'Hara's Restaurant & Pub",
#     'location': {'address': '120 Cedar St',
#      'crossStreet': 'at Greenwich St.',
#      'lat': 40.70989378141622,
#      'lng': -74.01283563128297,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.70989378141622,
#        'lng': -74.01283563128297},
#       {'label': 'entrance', 'lat': 40.709559, 'lng': -74.012621}],
#      'distance': 656,
#      'postalCode': '10006',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['120 Cedar St (at Greenwich St.)',
#       'New York, NY 10006',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d11b941735',
#       'name': 'Pub',
#       'pluralName': 'Pubs',
#       'shortName': 'Pub',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#        'suffix': '.png'},
#       'primary': True}],
#     'venuePage': {'id': '93216281'},
#     'referralId': 'v-1606590156',
#     'hasPerk': False},
#    {'id': '515f66e7e4b027e897d16e3c',
#     'name': 'Chinese Free Mason Athletic Association',
#     'location': {'lat': 40.71753591555177,
#      'lng': -73.99518388533123,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.71753591555177,
#        'lng': -73.99518388533123}],
#      'distance': 1059,
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['New York, NY', 'United States']},
#     'categories': [{'id': '50328a8e91d4c4b30a586d6c',
#       'name': 'Non-Profit',
#       'pluralName': 'Non-Profits',
#       'shortName': 'Non-Profit',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1606590156',
#     'hasPerk': False},
#    {'id': '3fd66200f964a520ceea1ee3',
#     'name': 'Deluxe Green Bo Restaurant',
#     'location': {'address': '66 Bayard St',
#      'crossStreet': 'btwn Elizabeth & Mott St',
#      'lat': 40.715544918133155,
#      'lng': -73.99813747002635,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.715544918133155,
#        'lng': -73.99813747002635},
#       {'label': 'entrance', 'lat': 40.715543, 'lng': -73.998033}],
#      'distance': 734,
#      'postalCode': '10013',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['66 Bayard St (btwn Elizabeth & Mott St)',
#       'New York, NY 10013',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d145941735',
#       'name': 'Chinese Restaurant',
#       'pluralName': 'Chinese Restaurants',
#       'shortName': 'Chinese',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'delivery': {'id': '546663',
#      'url': 'https://www.seamless.com/menu/deluxe-green-bo-restaurant-66-bayard-st-new-york/546663?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=546663',
#      'provider': {'name': 'seamless',
#       'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#        'sizes': [40, 50],
#        'name': '/delivery_provider_seamless_20180129.png'}}},
#     'venuePage': {'id': '348599123'},
#     'referralId': 'v-1606590156',
#     'hasPerk': False},
#    {'id': '4aaa8446f964a520465620e3',
#     'name': 'Chinese qi gong tui-na',
#     'location': {'address': '222 Lafayette St',
#      'crossStreet': 'Spring st',
#      'lat': 40.722103118896484,
#      'lng': -73.99768829345703,
#      'labeledLatLngs': [{'label': 'entrance',
#        'lat': 40.722056,
#        'lng': -73.997518},
#       {'label': 'display',
#        'lat': 40.722103118896484,
#        'lng': -73.99768829345703}],
#      'distance': 1258,
#      'postalCode': '10012',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['222 Lafayette St (Spring st)',
#       'New York, NY 10012',
#       'United States']},
#     'categories': [{'id': '52f2ab2ebcbc57f1066b8b3c',
#       'name': 'Massage Studio',
#       'pluralName': 'Massage Studios',
#       'shortName': 'Massage Studio',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/spa_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1606590157',
#     'hasPerk': False},
#    {'id': '3fd66200f964a520ece31ee3',
#     'name': 'Golden Unicorn Restaurant 麒麟金閣',
#     'location': {'address': '18 E Broadway',
#      'crossStreet': 'at Catherine St',
#      'lat': 40.713628504646834,
#      'lng': -73.99723023176193,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.713628504646834,
#        'lng': -73.99723023176193}],
#      'distance': 748,
#      'postalCode': '10002',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['18 E Broadway (at Catherine St)',
#       'New York, NY 10002',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1f5931735',
#       'name': 'Dim Sum Restaurant',
#       'pluralName': 'Dim Sum Restaurants',
#       'shortName': 'Dim Sum',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/dimsum_',
#        'suffix': '.png'},
#       'primary': True}],
#     'delivery': {'id': '2197825',
#      'url': 'https://www.seamless.com/menu/golden-unicorn-broadway-18-e-broadway-new-york/2197825?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=2197825',
#      'provider': {'name': 'seamless',
#       'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#        'sizes': [40, 50],
#        'name': '/delivery_provider_seamless_20180129.png'}}},
#     'venuePage': {'id': '72966848'},
#     'referralId': 'v-1606590157',
#     'hasPerk': False},
#    {'id': '45e5c256f964a52046431fe3',
#     'name': 'Mudville Restaurant & Tap House',
#     'location': {'address': '126 Chambers St',
#      'crossStreet': 'btwn W Broadway & Church St',
#      'lat': 40.71520852817451,
#      'lng': -74.00892327116395,
#      'labeledLatLngs': [{'label': 'entrance',
#        'lat': 40.715239,
#        'lng': -74.008849},
#       {'label': 'display',
#        'lat': 40.71520852817451,
#        'lng': -74.00892327116395}],
#      'distance': 369,
#      'postalCode': '10007',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['126 Chambers St (btwn W Broadway & Church St)',
#       'New York, NY 10007',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d14c941735',
#       'name': 'Wings Joint',
#       'pluralName': 'Wings Joints',
#       'shortName': 'Wings',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/wings_',
#        'suffix': '.png'},
#       'primary': True}],
#     'delivery': {'id': '299726',
#      'url': 'https://www.seamless.com/menu/mudville-restaurant-126-chambers-st-new-york/299726?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=299726',
#      'provider': {'name': 'seamless',
#       'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#        'sizes': [40, 50],
#        'name': '/delivery_provider_seamless_20180129.png'}}},
#     'venuePage': {'id': '43156651'},
#     'referralId': 'v-1606590157',
#     'hasPerk': False},
#    {'id': '4d9f5e228e8f224bcd8ca256',
#     'name': 'Chinese Wah Lai Funeral Home',
#     'location': {'address': '22 Mulberry St',
#      'lat': 40.71417,
#      'lng': -73.99941700000001,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.71417,
#        'lng': -73.99941700000001},
#       {'label': 'entrance', 'lat': 40.714179, 'lng': -73.999499}],
#      'distance': 579,
#      'postalCode': '10013',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['22 Mulberry St',
#       'New York, NY 10013',
#       'United States']},
#     'categories': [{'id': '4f4534884b9074f6e4fb0174',
#       'name': 'Funeral Home',
#       'pluralName': 'Funeral Homes',
#       'shortName': 'Funeral Home',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/funeralhome_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1606590157',
#     'hasPerk': False},
#    {'id': '49c68407f964a52052571fe3',
#     'name': 'Chatham Seafood Restaurant',
#     'location': {'address': '6 Chatham Sq',
#      'crossStreet': 'btwn Mott & Doyers St',
#      'lat': 40.71388466954485,
#      'lng': -73.99826556444168,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.71388466954485,
#        'lng': -73.99826556444168},
#       {'label': 'entrance', 'lat': 40.713832, 'lng': -73.998235}],
#      'distance': 666,
#      'postalCode': '10038',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['6 Chatham Sq (btwn Mott & Doyers St)',
#       'New York, NY 10038',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1f5931735',
#       'name': 'Dim Sum Restaurant',
#       'pluralName': 'Dim Sum Restaurants',
#       'shortName': 'Dim Sum',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/dimsum_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1606590157',
#     'hasPerk': False},
#    {'id': '4bf978b5bc869521a6b97a6b',
#     'name': 'OCM - Oversea Chinese Mission',
#     'location': {'address': '154 Hester St',
#      'crossStreet': 'at Elizabeth St.',
#      'lat': 40.717563959884664,
#      'lng': -73.99644379172986,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.717563959884664,
#        'lng': -73.99644379172986},
#       {'label': 'entrance', 'lat': 40.71759, 'lng': -73.996545}],
#      'distance': 970,
#      'postalCode': '10013',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['154 Hester St (at Elizabeth St.)',
#       'New York, NY 10013',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d132941735',
#       'name': 'Church',
#       'pluralName': 'Churches',
#       'shortName': 'Church',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/religious_church_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1606590157',
#     'hasPerk': False},
#    {'id': '4cda14c3d4ecb1f735d17148',
#     'name': 'Chinese Community Center',
#     'location': {'address': '62 Mott St',
#      'lat': 40.7159147054148,
#      'lng': -73.9981049029518,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.7159147054148,
#        'lng': -73.9981049029518}],
#      'distance': 755,
#      'postalCode': '10013',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['62 Mott St',
#       'New York, NY 10013',
#       'United States']},
#     'categories': [{'id': '52e81612bcbc57f1066b7a34',
#       'name': 'Community Center',
#       'pluralName': 'Community Centers',
#       'shortName': 'Community Center',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1606590157',
#     'hasPerk': False},
#    {'id': '49f50c47f964a520896b1fe3',
#     'name': 'XO Kitchen',
#     'location': {'address': '148 Hester St',
#      'crossStreet': 'btw Bowery & Elizabeth',
#      'lat': 40.71748184806784,
#      'lng': -73.99604732552757,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.71748184806784,
#        'lng': -73.99604732552757},
#       {'label': 'entrance', 'lat': 40.717476, 'lng': -73.996212}],
#      'distance': 993,
#      'postalCode': '10013',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['148 Hester St (btw Bowery & Elizabeth)',
#       'New York, NY 10013',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d145941735',
#       'name': 'Chinese Restaurant',
#       'pluralName': 'Chinese Restaurants',
#       'shortName': 'Chinese',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1606590157',
#     'hasPerk': False},
#    {'id': '4bf2dc586ba2b713560c8977',
#     'name': 'Chinese American IPA',
#     'location': {'address': '41 Elizabeth St',
#      'lat': 40.71972928254605,
#      'lng': -73.99996176189606,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.71972928254605,
#        'lng': -73.99996176189606}],
#      'distance': 931,
#      'postalCode': '10013',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['41 Elizabeth St',
#       'New York, NY 10013',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d124941735',
#       'name': 'Office',
#       'pluralName': 'Offices',
#       'shortName': 'Office',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1606590157',
#     'hasPerk': False},
#    {'id': '3fd66200f964a520d7e41ee3',
#     'name': 'Stone Street Tavern',
#     'location': {'address': '52 Stone St',
#      'crossStreet': 'btwn Broad St & Hanover Sq',
#      'lat': 40.70432253999865,
#      'lng': -74.01025004936773,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.70432253999865,
#        'lng': -74.01025004936773},
#       {'label': 'entrance', 'lat': 40.704295, 'lng': -74.010295}],
#      'distance': 1001,
#      'postalCode': '10004',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['52 Stone St (btwn Broad St & Hanover Sq)',
#       'New York, NY 10004',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d11b941735',
#       'name': 'Pub',
#       'pluralName': 'Pubs',
#       'shortName': 'Pub',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1606590157',
#     'hasPerk': False},
#    {'id': '4c5c7cdf9b28d13a5ef25670',
#     'name': 'Chinese Qigong Tui-Na',
#     'location': {'address': '68 White St',
#      'crossStreet': 'Broadway',
#      'lat': 40.71838974952698,
#      'lng': -74.00427639484406,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.71838974952698,
#        'lng': -74.00427639484406}],
#      'distance': 647,
#      'postalCode': '10013',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['68 White St (Broadway)',
#       'New York, NY 10013',
#       'United States']},
#     'categories': [],
#     'referralId': 'v-1606590157',
#     'hasPerk': False},
#    {'id': '4a00df67f964a520ba701fe3',
#     'name': 'Bo Ky Restaurant 波記潮州小食',
#     'location': {'address': '80 Bayard St',
#      'crossStreet': 'at Mott St',
#      'lat': 40.71569636637641,
#      'lng': -73.99866703526523,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.71569636637641,
#        'lng': -73.99866703526523},
#       {'label': 'entrance', 'lat': 40.715779, 'lng': -73.9987}],
#      'distance': 702,
#      'postalCode': '10013',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['80 Bayard St (at Mott St)',
#       'New York, NY 10013',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d145941735',
#       'name': 'Chinese Restaurant',
#       'pluralName': 'Chinese Restaurants',
#       'shortName': 'Chinese',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1606590157',
#     'hasPerk': False},
#    {'id': '51be2d6f498e7a73436bd59a',
#     'name': 'Chinese Qigong Massage',
#     'location': {'address': '68 White St',
#      'crossStreet': 'Broadway And Church',
#      'lat': 40.718223571777344,
#      'lng': -74.00328063964844,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.718223571777344,
#        'lng': -74.00328063964844}],
#      'distance': 653,
#      'postalCode': '10013',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['68 White St (Broadway And Church)',
#       'New York, NY 10013',
#       'United States']},
#     'categories': [{'id': '52f2ab2ebcbc57f1066b8b3c',
#       'name': 'Massage Studio',
#       'pluralName': 'Massage Studios',
#       'shortName': 'Massage Studio',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/spa_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1606590157',
#     'hasPerk': False},
#    {'id': '5176d244e4b08669e975294b',
#     'name': 'Chinese Opera Society',
#     'location': {'lat': 40.707793,
#      'lng': -74.011045,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.707793,
#        'lng': -74.011045}],
#      'distance': 694,
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['New York, NY', 'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1f1931735',
#       'name': 'General Entertainment',
#       'pluralName': 'General Entertainment',
#       'shortName': 'Entertainment',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1606590157',
#     'hasPerk': False},
#    {'id': '5a18852e67e5f2622db4c44b',
#     'name': 'Chinese Musical Society',
#     'location': {'address': '24 Pell St',
#      'lat': 40.715023,
#      'lng': -73.99818,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.715023,
#        'lng': -73.99818}],
#      'distance': 708,
#      'postalCode': '10013',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['24 Pell St',
#       'New York, NY 10013',
#       'United States']},
#     'categories': [{'id': '4f04b10d2fb6e1c99f3db0be',
#       'name': 'Music School',
#       'pluralName': 'Music Schools',
#       'shortName': 'Music School',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/school_music_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1606590157',
#     'hasPerk': False},
#    {'id': '4fb55666e4b013e612e5fb5e',
#     'name': 'Chinese Herb & Acupressure',
#     'location': {'address': '59 Mott St',
#      'crossStreet': 'Bayard St.',
#      'lat': 40.715996999999994,
#      'lng': -73.998565,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.715996999999994,
#        'lng': -73.998565},
#       {'label': 'entrance', 'lat': 40.715941, 'lng': -73.998405}],
#      'distance': 726,
#      'postalCode': '10013',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['59 Mott St (Bayard St.)',
#       'New York, NY 10013',
#       'United States']},
#     'categories': [{'id': '52e81612bcbc57f1066b7a3b',
#       'name': 'Acupuncturist',
#       'pluralName': 'Acupuncturists',
#       'shortName': 'Acupuncturist',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_doctorsoffice_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1606590157',
#     'hasPerk': False},
#    {'id': '5031351fe4b0adcbed80260f',
#     'name': 'Chinese Herbs Tuina',
#     'location': {'address': '63 Mott St',
#      'crossStreet': 'Canal St',
#      'lat': 40.716124,
#      'lng': -73.998499,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.716124,
#        'lng': -73.998499},
#       {'label': 'entrance', 'lat': 40.716065, 'lng': -73.998322}],
#      'distance': 738,
#      'postalCode': '10013',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['63 Mott St (Canal St)',
#       'New York, NY 10013',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1ed941735',
#       'name': 'Spa',
#       'pluralName': 'Spas',
#       'shortName': 'Spa',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/spa_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1606590157',
#     'hasPerk': False},
#    {'id': '4b4fdfc8f964a520801827e3',
#     'name': 'TJ Byrnes Bar and Restaurant',
#     'location': {'address': '77 Fulton St',
#      'crossStreet': 'Gold St',
#      'lat': 40.70923312629616,
#      'lng': -74.00374736164414,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.70923312629616,
#        'lng': -74.00374736164414}],
#      'distance': 433,
#      'postalCode': '10038',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['77 Fulton St (Gold St)',
#       'New York, NY 10038',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1c4941735',
#       'name': 'Restaurant',
#       'pluralName': 'Restaurants',
#       'shortName': 'Restaurant',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'delivery': {'id': '64746',
#      'url': 'https://www.seamless.com/menu/tj-byrnes-77-fulton-st-new-york/64746?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=64746',
#      'provider': {'name': 'seamless',
#       'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#        'sizes': [40, 50],
#        'name': '/delivery_provider_seamless_20180129.png'}}},
#     'venuePage': {'id': '131643631'},
#     'referralId': 'v-1606590157',
#     'hasPerk': False},
#    {'id': '4c8fda03590ab1f7c76de27d',
#     'name': 'Chinese American Planning Council',
#     'location': {'address': '150 Elizabeth St',
#      'crossStreet': 'Kenmare St',
#      'lat': 40.72036386347542,
#      'lng': -73.99498828127511,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.72036386347542,
#        'lng': -73.99498828127511}],
#      'distance': 1260,
#      'postalCode': '10012',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['150 Elizabeth St (Kenmare St)',
#       'New York, NY 10012',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d124941735',
#       'name': 'Office',
#       'pluralName': 'Offices',
#       'shortName': 'Office',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1606590157',
#     'hasPerk': False},
#    {'id': '4a81ac53f964a5203af71fe3',
#     'name': 'Sun Sai Gai Restaurant',
#     'location': {'address': '220 Canal St',
#      'crossStreet': 'at Baxter St',
#      'lat': 40.71736941942955,
#      'lng': -73.9994145838037,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.71736941942955,
#        'lng': -73.9994145838037},
#       {'label': 'entrance', 'lat': 40.717217, 'lng': -73.999354}],
#      'distance': 759,
#      'postalCode': '10013',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['220 Canal St (at Baxter St)',
#       'New York, NY 10013',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d145941735',
#       'name': 'Chinese Restaurant',
#       'pluralName': 'Chinese Restaurants',
#       'shortName': 'Chinese',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1606590157',
#     'hasPerk': False},
#    {'id': '4bc238adf8219c744286b410',
#     'name': "Amore's Pizza Restaurant",
#     'location': {'address': '147 Chambers St',
#      'crossStreet': 'Hudson Street',
#      'lat': 40.715859606149245,
#      'lng': -74.00988835781403,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.715859606149245,
#        'lng': -74.00988835781403},
#       {'label': 'entrance', 'lat': 40.715854, 'lng': -74.009749}],
#      'distance': 477,
#      'postalCode': '10007',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['147 Chambers St (Hudson Street)',
#       'New York, NY 10007',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1ca941735',
#       'name': 'Pizza Place',
#       'pluralName': 'Pizza Places',
#       'shortName': 'Pizza',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#        'suffix': '.png'},
#       'primary': True}],
#     'delivery': {'id': '1431324',
#      'url': 'https://www.seamless.com/menu/cafe-amores-pizzeria-ristorante-147-chambers-st-new-york/1431324?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=1431324',
#      'provider': {'name': 'seamless',
#       'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#        'sizes': [40, 50],
#        'name': '/delivery_provider_seamless_20180129.png'}}},
#     'referralId': 'v-1606590157',
#     'hasPerk': False},
#    {'id': '4f3259a219836c91c7cf1778',
#     'name': 'Lei Ke Massage and Chinese Herbal Medicine',
#     'location': {'address': '265 Canal St',
#      'lat': 40.718838,
#      'lng': -74.000785,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.718838,
#        'lng': -74.000785}],
#      'distance': 810,
#      'postalCode': '10013',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['265 Canal St',
#       'New York, NY 10013',
#       'United States']},
#     'categories': [{'id': '4d4b7105d754a06374d81259',
#       'name': 'Food',
#       'pluralName': 'Food',
#       'shortName': 'Food',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1606590157',
#     'hasPerk': False},
#    {'id': '3fd66200f964a520ade61ee3',
#     'name': 'Puglia Restaurant',
#     'location': {'address': '189 Hester St',
#      'crossStreet': 'btwn Mott & Mulberry',
#      'lat': 40.718165114645075,
#      'lng': -73.99782187292207,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.718165114645075,
#        'lng': -73.99782187292207},
#       {'label': 'entrance', 'lat': 40.718147, 'lng': -73.997688}],
#      'distance': 918,
#      'postalCode': '10013',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['189 Hester St (btwn Mott & Mulberry)',
#       'New York, NY 10013',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d110941735',
#       'name': 'Italian Restaurant',
#       'pluralName': 'Italian Restaurants',
#       'shortName': 'Italian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1606590157',
#     'hasPerk': False},
#    {'id': '4a8d9afef964a520351020e3',
#     'name': 'Xe Lửa Vietnamese Restaurant',
#     'location': {'address': '86 Mulberry St',
#      'crossStreet': 'btwn Canal & Bayard St',
#      'lat': 40.716620265261156,
#      'lng': -73.99877836410754,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.716620265261156,
#        'lng': -73.99877836410754},
#       {'label': 'entrance', 'lat': 40.716605, 'lng': -73.998796}],
#      'distance': 748,
#      'postalCode': '10013',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['86 Mulberry St (btwn Canal & Bayard St)',
#       'New York, NY 10013',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d14a941735',
#       'name': 'Vietnamese Restaurant',
#       'pluralName': 'Vietnamese Restaurants',
#       'shortName': 'Vietnamese',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/vietnamese_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1606590157',
#     'hasPerk': False},
#    {'id': '4bfdcd3ae529c928a589bb8c',
#     'name': '218 Restaurant',
#     'location': {'address': '218 Grand St',
#      'crossStreet': 'btwn Elizabeth & Mott St.',
#      'lat': 40.71883283355385,
#      'lng': -73.99589513199142,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.71883283355385,
#        'lng': -73.99589513199142},
#       {'label': 'entrance', 'lat': 40.718934, 'lng': -73.995845}],
#      'distance': 1091,
#      'postalCode': '10013',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['218 Grand St (btwn Elizabeth & Mott St.)',
#       'New York, NY 10013',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d145941735',
#       'name': 'Chinese Restaurant',
#       'pluralName': 'Chinese Restaurants',
#       'shortName': 'Chinese',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1606590157',
#     'hasPerk': False},
#    {'id': '4ed10e9db634dd2992446d6a',
#     'name': '123 Mott St Chinese Herbal Store',
#     'location': {'address': '123 Mott St',
#      'lat': 40.718171999999996,
#      'lng': -73.997114,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.718171999999996,
#        'lng': -73.997114},
#       {'label': 'entrance', 'lat': 40.718123, 'lng': -73.997052}],
#      'distance': 965,
#      'postalCode': '10013',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['123 Mott St',
#       'New York, NY 10013',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d10f951735',
#       'name': 'Pharmacy',
#       'pluralName': 'Pharmacies',
#       'shortName': 'Pharmacy',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/pharmacy_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1606590157',
#     'hasPerk': False},
#    {'id': '4ebaede0a17c5dccac5210f7',
#     'name': 'Wall Street Chinese',
#     'location': {'address': '32 Broadway',
#      'lat': 40.705794,
#      'lng': -74.012721,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.705794,
#        'lng': -74.012721},
#       {'label': 'entrance', 'lat': 40.705918, 'lng': -74.013026}],
#      'distance': 957,
#      'postalCode': '10004',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['32 Broadway',
#       'New York, NY 10004',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1f1931735',
#       'name': 'General Entertainment',
#       'pluralName': 'General Entertainment',
#       'shortName': 'Entertainment',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1606590157',
#     'hasPerk': False},
#    {'id': '582543c1b39f9613c18d8e2f',
#     'name': 'Chinese Tuxedo',
#     'location': {'address': '5 Doyers St',
#      'lat': 40.71443328935857,
#      'lng': -73.99798682863612,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.71443328935857,
#        'lng': -73.99798682863612}],
#      'distance': 703,
#      'postalCode': '10013',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['5 Doyers St',
#       'New York, NY 10013',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d145941735',
#       'name': 'Chinese Restaurant',
#       'pluralName': 'Chinese Restaurants',
#       'shortName': 'Chinese',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1606590157',
#     'hasPerk': False}]}}

# %%
# assign relevant part of JSON to venues
venues = results['response']['venues']

# tranform venues into a dataframe
dataframe = json_normalize(venues)
dataframe.head()
# Out:
#                          id                                    name  \
# 0  58aa398b14fb41097a0cf923  Great Fortune Chinese Restaurant 聚旺茶餐廳
# 1  4e4463cf52b18fcc799a9761       88 Reach House chinese restaurant
# 2  581299bb38fa2e54303f6891                Taste Chinese Restaurant
# 3  4b54fcddf964a520bfd627e3            Food King Chinese Restaurant
# 4  4e4e4c7abd4101d0d7a72532          Dragon Gate Chinese Restaurant
#
#                                           categories    referralId  hasPerk  \
# 0  [{'id': '52af3a7c3cf9994f4e043bed', 'name': 'C...  v-1606590156    False
# 1  [{'id': '4bf58dd8d48988d145941735', 'name': 'C...  v-1606590156    False
# 2  [{'id': '4bf58dd8d48988d145941735', 'name': 'C...  v-1606590156    False
# 3  [{'id': '4bf58dd8d48988d145941735', 'name': 'C...  v-1606590156    False
# 4  [{'id': '4bf58dd8d48988d145941735', 'name': 'C...  v-1606590156    False
#
#   location.address          location.crossStreet  location.lat  location.lng  \
# 0   5 Catherine St  btwn E Broadway & Chatham Sq     40.713875    -73.997280
# 1   88 Division St                Eldrige street     40.714468    -73.993727
# 2    178 Church St                           NaN     40.715690    -74.007605
# 3     56 Market St                        Monroe     40.711606    -73.994186
# 4  92 Elizabeth St                           NaN     40.718358    -73.995632
#
#                              location.labeledLatLngs  ...  location.state  \
# 0  [{'label': 'display', 'lat': 40.713875, 'lng':...  ...              NY
# 1  [{'label': 'display', 'lat': 40.714468, 'lng':...  ...              NY
# 2  [{'label': 'display', 'lat': 40.7156902, 'lng'...  ...              NY
# 3  [{'label': 'display', 'lat': 40.71160573939490...  ...              NY
# 4  [{'label': 'display', 'lat': 40.718358, 'lng':...  ...              NY
#
#   location.country                          location.formattedAddress  \
# 0    United States  [5 Catherine St (btwn E Broadway & Chatham Sq)...
# 1    United States  [88 Division St (Eldrige street), New York, NY...
# 2    United States  [178 Church St, New York, NY 10013, United Sta...
# 3    United States  [56 Market St (Monroe), New York, NY 10002, Un...
# 4    United States  [92 Elizabeth St, New York, NY 10013, United S...
#
#   delivery.id                                       delivery.url  \
# 0         NaN                                                NaN
# 1         NaN                                                NaN
# 2      322507  https://www.seamless.com/menu/taste-chinese-re...
# 3         NaN                                                NaN
# 4         NaN                                                NaN
#
#   delivery.provider.name             delivery.provider.icon.prefix  \
# 0                    NaN                                       NaN
# 1                    NaN                                       NaN
# 2               seamless  https://fastly.4sqi.net/img/general/cap/
# 3                    NaN                                       NaN
# 4                    NaN                                       NaN
#
#   delivery.provider.icon.sizes               delivery.provider.icon.name  \
# 0                          NaN                                       NaN
# 1                          NaN                                       NaN
# 2                     [40, 50]  /delivery_provider_seamless_20180129.png
# 3                          NaN                                       NaN
# 4                          NaN                                       NaN
#
#   venuePage.id
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
#
# [5 rows x 24 columns]

# %%
dataframe.shape
# Out:
# (50, 24)

# %% [markdown]
# Define information of interest and filter dataframe

# %%
# keep only columns that include venue name, and anything that is associated with location
filtered_columns = ['name', 'categories'] + [col for col in dataframe.columns if col.startswith('location.')] + ['id']
dataframe_filtered = dataframe.loc[:, filtered_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# filter the category for each row
dataframe_filtered['categories'] = dataframe_filtered.apply(get_category_type, axis=1)

# clean column names by keeping only last term
dataframe_filtered.columns = [column.split('.')[-1] for column in dataframe_filtered.columns]

dataframe_filtered.head(10)
# Out:
#                                      name            categories  \
# 0  Great Fortune Chinese Restaurant 聚旺茶餐廳  Cantonese Restaurant
# 1       88 Reach House chinese restaurant    Chinese Restaurant
# 2                Taste Chinese Restaurant    Chinese Restaurant
# 3            Food King Chinese Restaurant    Chinese Restaurant
# 4          Dragon Gate Chinese Restaurant    Chinese Restaurant
# 5             Downtown Chinese Restaurant                  Food
# 6                Ann's Chinese Restaurant      Asian Restaurant
# 7         Malasia-Thai-Chinese Restaurant      Asian Restaurant
# 8           Marco Polo Chinese Restaurant    Chinese Restaurant
# 9      Fu Zhou An Ping Chinese Restaurant      Asian Restaurant
#
#              address                   crossStreet        lat        lng  \
# 0     5 Catherine St  btwn E Broadway & Chatham Sq  40.713875 -73.997280
# 1     88 Division St                Eldrige street  40.714468 -73.993727
# 2      178 Church St                           NaN  40.715690 -74.007605
# 3       56 Market St                        Monroe  40.711606 -73.994186
# 4    92 Elizabeth St                           NaN  40.718358 -73.995632
# 5        135 John St                           NaN  40.707134 -74.004944
# 6  1 E Broadway #2FL                           NaN  40.713154 -73.997955
# 7                NaN                           NaN  40.717035 -73.999719
# 8       94 Baxter St                           NaN  40.716920 -73.999419
# 9        20 Henry St                           NaN  40.712723 -73.996880
#
#                                       labeledLatLngs  distance postalCode  cc  \
# 0  [{'label': 'display', 'lat': 40.713875, 'lng':...       748      10038  US
# 1  [{'label': 'display', 'lat': 40.714468, 'lng':...      1054      10002  US
# 2  [{'label': 'display', 'lat': 40.7156902, 'lng'...       355      10013  US
# 3  [{'label': 'display', 'lat': 40.71160573939490...      1005      10002  US
# 4  [{'label': 'display', 'lat': 40.718358, 'lng':...      1077      10013  US
# 5  [{'label': 'entrance', 'lat': 40.707098, 'lng'...       629      10038  US
# 6  [{'label': 'display', 'lat': 40.71315383911133...       681      10038  US
# 7  [{'label': 'display', 'lat': 40.717035, 'lng':...       715      10013  US
# 8  [{'label': 'display', 'lat': 40.71692037258939...       726      10013  US
# 9  [{'label': 'display', 'lat': 40.71272277832031...       770      10002  US
#
#        city state        country  \
# 0  New York    NY  United States
# 1  New York    NY  United States
# 2  New York    NY  United States
# 3  New York    NY  United States
# 4  New York    NY  United States
# 5  New York    NY  United States
# 6  New York    NY  United States
# 7  New York    NY  United States
# 8  New York    NY  United States
# 9  New York    NY  United States
#
#                                     formattedAddress                        id
# 0  [5 Catherine St (btwn E Broadway & Chatham Sq)...  58aa398b14fb41097a0cf923
# 1  [88 Division St (Eldrige street), New York, NY...  4e4463cf52b18fcc799a9761
# 2  [178 Church St, New York, NY 10013, United Sta...  581299bb38fa2e54303f6891
# 3  [56 Market St (Monroe), New York, NY 10002, Un...  4b54fcddf964a520bfd627e3
# 4  [92 Elizabeth St, New York, NY 10013, United S...  4e4e4c7abd4101d0d7a72532
# 5   [135 John St, New York, NY 10038, United States]  4f320f6d19833175d60c8d97
# 6  [1 E Broadway #2FL, New York, NY 10038, United...  5012c0fde4b0748a78b0c886
# 7                [New York, NY 10013, United States]  50b043dbe4b0be4ddec7cf6a
# 8  [94 Baxter St, New York, NY 10013, United States]  4e4e4c65bd4101d0d7a723cb
# 9   [20 Henry St, New York, NY 10002, United States]  58913f12288b6a0e789bb237

# %% [markdown]
# Let's visualize the Chinese restaurants that are nearby

# %%
venues_map = folium.Map(location=[latitude, longitude], zoom_start=13) # generate map 

# add a red circle marker to represent the center of New York City
folium.CircleMarker(
    [latitude, longitude],
    radius=10,
    color='red',
    popup='Center',
    fill = True,
    fill_color = 'red',
    fill_opacity = 0.6
).add_to(venues_map)

# add the Chinese restaurants as blue circle markers
for lat, lng, label in zip(dataframe_filtered.lat, dataframe_filtered.lng, dataframe_filtered.categories):
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        color='blue',
        popup=label,
        fill = True,
        fill_color='blue',
        fill_opacity=0.6
    ).add_to(venues_map)

# display map
venues_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# #### Select out the restaurants that are rated

# %%
rated_restaurant = []
rating = []
for i in range(dataframe_filtered.shape[0]):
    venue_id = dataframe_filtered.loc[i, 'id']
    url = 'https://api.foursquare.com/v2/venues/{}?client_id={}&client_secret={}&v={}'.format(venue_id, CLIENT_ID, CLIENT_SECRET, VERSION)
    result = requests.get(url).json()
    try:
        print(result['response']['venue']['rating'])
        rated_restaurant.append(dataframe_filtered.iloc[i])
        rating.append(result['response']['venue']['rating'])
    
    except:
        print('This venue has not been rated yet.')
# Out:
# This venue has not been rated yet.
# This venue has not been rated yet.
# This venue has not been rated yet.
# This venue has not been rated yet.
# This venue has not been rated yet.
# This venue has not been rated yet.
# This venue has not been rated yet.
# This venue has not been rated yet.
# This venue has not been rated yet.
# This venue has not been rated yet.
# 5.5
# This venue has not been rated yet.
# This venue has not been rated yet.
# This venue has not been rated yet.
# This venue has not been rated yet.
# This venue has not been rated yet.
# 5.6
# 8.0
# 8.7
# 8.3
# This venue has not been rated yet.
# 8.0
# This venue has not been rated yet.
# 8.0
# 7.5
# This venue has not been rated yet.
# 7.1
# This venue has not been rated yet.
# This venue has not been rated yet.
# 6.7
# This venue has not been rated yet.
# 7.4
# This venue has not been rated yet.
# 8.0
# This venue has not been rated yet.
# This venue has not been rated yet.
# This venue has not been rated yet.
# This venue has not been rated yet.
# This venue has not been rated yet.
# 7.1
# This venue has not been rated yet.
# 6.6
# 6.4
# This venue has not been rated yet.
# 7.8
# 7.5
# 7.2
# This venue has not been rated yet.
# This venue has not been rated yet.
# 7.3

# %% [markdown]
# Combine the basic info of restaurants that are rated and their rating

# %%
from pandas import DataFrame
rated_restaurant2 = DataFrame(rated_restaurant)
rated_restaurant2['rating'] = rating
rated_restaurant3 = rated_restaurant2[rated_restaurant2['categories'].str.contains("Chinese")].reset_index(drop=True)
rated_restaurant3
# Out:
#                             name          categories          address  \
# 0  Canal Best Chinese Restaurant  Chinese Restaurant     266 Canal St
# 1             Number One Chinese  Chinese Restaurant  10 S William St
# 2     Deluxe Green Bo Restaurant  Chinese Restaurant     66 Bayard St
# 3                     XO Kitchen  Chinese Restaurant    148 Hester St
# 4        Bo Ky Restaurant 波記潮州小食  Chinese Restaurant     80 Bayard St
# 5         Sun Sai Gai Restaurant  Chinese Restaurant     220 Canal St
# 6                 218 Restaurant  Chinese Restaurant     218 Grand St
# 7                 Chinese Tuxedo  Chinese Restaurant      5 Doyers St
#
#                  crossStreet        lat        lng  \
# 0                        NaN  40.718790 -74.001055
# 1                        NaN  40.704574 -74.010410
# 2   btwn Elizabeth & Mott St  40.715545 -73.998137
# 3     btw Bowery & Elizabeth  40.717482 -73.996047
# 4                 at Mott St  40.715696 -73.998667
# 5               at Baxter St  40.717369 -73.999415
# 6  btwn Elizabeth & Mott St.  40.718833 -73.995895
# 7                        NaN  40.714433 -73.997987
#
#                                       labeledLatLngs  distance postalCode  cc  \
# 0  [{'label': 'display', 'lat': 40.71878993882605...       794      10013  US
# 1  [{'label': 'display', 'lat': 40.70457357537987...       980      10004  US
# 2  [{'label': 'display', 'lat': 40.71554491813315...       734      10013  US
# 3  [{'label': 'display', 'lat': 40.71748184806784...       993      10013  US
# 4  [{'label': 'display', 'lat': 40.71569636637641...       702      10013  US
# 5  [{'label': 'display', 'lat': 40.71736941942955...       759      10013  US
# 6  [{'label': 'display', 'lat': 40.71883283355385...      1091      10013  US
# 7  [{'label': 'display', 'lat': 40.71443328935857...       703      10013  US
#
#        city state        country  \
# 0  New York    NY  United States
# 1  New York    NY  United States
# 2  New York    NY  United States
# 3  New York    NY  United States
# 4  New York    NY  United States
# 5  New York    NY  United States
# 6  New York    NY  United States
# 7  New York    NY  United States
#
#                                     formattedAddress  \
# 0  [266 Canal St, New York, NY 10013, United States]
# 1  [10 S William St, New York, NY 10004, United S...
# 2  [66 Bayard St (btwn Elizabeth & Mott St), New ...
# 3  [148 Hester St (btw Bowery & Elizabeth), New Y...
# 4  [80 Bayard St (at Mott St), New York, NY 10013...
# 5  [220 Canal St (at Baxter St), New York, NY 100...
# 6  [218 Grand St (btwn Elizabeth & Mott St.), New...
# 7   [5 Doyers St, New York, NY 10013, United States]
#
#                          id  rating
# 0  4d83993c81fdb1f7cf87eabf     5.5
# 1  4ce56fbd5bf68cfa65f23c17     5.6
# 2  3fd66200f964a520ceea1ee3     8.0
# 3  49f50c47f964a520896b1fe3     6.7
# 4  4a00df67f964a520ba701fe3     8.0
# 5  4a81ac53f964a5203af71fe3     6.6
# 6  4bfdcd3ae529c928a589bb8c     7.2
# 7  582543c1b39f9613c18d8e2f     7.3

# %% [markdown]
# #### Make sure whether Los Angeles has specific restaurant

# %% [markdown]
# We select restaurant with highest rating to focus, so from the above datafame we can see that the highest rating is 8.0, and the restaurants are "Deluxe Green Bo Restaurant" and "Bo Ky Restaurant". Let's try "Deluxe Green Bo Restaurant" first. If Los Angeles does not have this restaurant, we will focus on this restaurant.

# %% [markdown]
# #### Find the latitude and longtitude of the Los Angeles.

# %%
address = 'Los Angeles, CA'

geolocator = Nominatim(user_agent="ca_explorer")
location = geolocator.geocode(address)
latitude_ca = location.latitude
longitude_ca = location.longitude
print('The geograpical coordinate of Los Angeles are {}, {}.'.format(latitude_ca, longitude_ca))
# Out:
# The geograpical coordinate of Los Angeles are 34.0536909, -118.2427666.

# %% [markdown]
# #### Search 'Deluxe Green Bo Restaurant' in Los Angeles

# %%
search_query = 'Deluxe Green Bo Restaurant'
radius = 1000
Limit = 3
print(search_query + ' .... OK!')
# Out:
# Deluxe Green Bo Restaurant .... OK!

# %%
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude_ca, longitude_ca, VERSION, search_query, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=2ZWXTA4YRRBQ3HWROURUTABBCBM4NOKA15FQTDWAM11GSNAR&client_secret=KKSVPPAEEG35XTZN1SWT0VV5WJF5JMJ5C4HYE3KR0I3LBUI3&ll=34.0536909,-118.2427666&v=20200715&query=Deluxe Green Bo Restaurant&radius=1000&limit=50'

# %%
results = requests.get(url).json()
# assign relevant part of JSON to venues
venues = results['response']['venues']

# tranform venues into a dataframe
dataframe2 = json_normalize(venues)
dataframe2.shape
# Out:
# (0, 0)

# %% [markdown]
# We can see that the dataframe we got has nothing in it, so there is no 'Deluxe Green Bo Restaurant' in Los Angeles

# %% [markdown]
# ## Try to find an optimal place for "Deluxe Green Bo Restaurant" to open a new restaurant in Los Angeles

# %% [markdown]
# #### Find the latitude and longtitude of the "Deluxe Green Bo Restaurant"

# %%
restaurant_name = rated_restaurant3.loc[2, 'name'] # restaurant name
restaurant_latitude = rated_restaurant3.loc[2, 'lat'] # restaurant latitude value
restaurant_longitude = rated_restaurant3.loc[2, 'lng'] # restaurant longitude value
print('Latitude and longitude values of {} are {}, {}.'.format(restaurant_name, 
                                                               restaurant_latitude, 
                                                               restaurant_longitude))
# Out:
# Latitude and longitude values of Deluxe Green Bo Restaurant are 40.715544918133155, -73.99813747002635.

# %% [markdown]
# #### Get neighborhoods (nearby venues) around "Deluxe Green Bo Restaurant"

# %%
LIMIT = 100 # limit of number of venues returned by Foursquare API
radius = 500 # define radius
url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
    CLIENT_ID, 
    CLIENT_SECRET, 
    VERSION, 
    restaurant_latitude, 
    restaurant_longitude, 
    radius, 
    LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/explore?&client_id=2ZWXTA4YRRBQ3HWROURUTABBCBM4NOKA15FQTDWAM11GSNAR&client_secret=KKSVPPAEEG35XTZN1SWT0VV5WJF5JMJ5C4HYE3KR0I3LBUI3&v=20200715&ll=40.715544918133155,-73.99813747002635&radius=500&limit=100'

# %%
results = requests.get(url).json()

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# %%
venues = results['response']['groups'][0]['items']
    
nearby_venues = json_normalize(venues) # flatten JSON

# filter columns
filtered_columns = ['venue.name', 'venue.categories', 'venue.location.lat', 'venue.location.lng']
nearby_venues =nearby_venues.loc[:, filtered_columns]

# filter the category for each row
nearby_venues['venue.categories'] = nearby_venues.apply(get_category_type, axis=1)

# clean columns
nearby_venues.columns = [col.split(".")[-1] for col in nearby_venues.columns]

nearby_venues.head()
# Out:
#                                        name           categories        lat  \
# 0                               Zu Yuan Spa                  Spa  40.715469
# 1                           Hotel 50 Bowery                Hotel  40.715936
# 2  The Original Chinatown Ice Cream Factory       Ice Cream Shop  40.715521
# 3                        Xi'an Famous Foods   Chinese Restaurant  40.715232
# 4                               Shanghai 21  Shanghai Restaurant  40.714423
#
#          lng
# 0 -73.998627
# 1 -73.996789
# 2 -73.998145
# 3 -73.997263
# 4 -73.998904

# %%
print('There are {} unique categories.'.format(len(nearby_venues['categories'].unique())))
# Out:
# There are 44 unique categories.

# %%
nearby_venues_grouped = nearby_venues.groupby('categories').count().reset_index()
nearby_venues_grouped_rank = nearby_venues_grouped.sort_values(by=['name'], ascending=False).reset_index()
nearby_venues_grouped_rank
# Out:
#     index                     categories  name  lat  lng
# 0       7             Chinese Restaurant    18   18   18
# 1       1                         Bakery     7    7    7
# 2      11                   Dessert Shop     5    5    5
# 3      12             Dim Sum Restaurant     5    5    5
# 4       3                Bubble Tea Shop     4    4    4
# 5      34             Salon / Barbershop     4    4    4
# 6      22             Italian Restaurant     3    3    3
# 7      35            Shanghai Restaurant     3    3    3
# 8      37                            Spa     3    3    3
# 9      27                   Noodle House     3    3    3
# 10     10                 Cosmetics Shop     2    2    2
# 11     38                    Supermarket     2    2    2
# 12     39           Taiwanese Restaurant     2    2    2
# 13     28                   Optical Shop     2    2    2
# 14     40                       Tea Room     2    2    2
# 15     25               Malay Restaurant     2    2    2
# 16     24                  Jewelry Store     2    2    2
# 17      9                    Coffee Shop     2    2    2
# 18     20              Hotpot Restaurant     2    2    2
# 19     21                 Ice Cream Shop     2    2    2
# 20     42          Vietnamese Restaurant     2    2    2
# 21     30         Peking Duck Restaurant     1    1    1
# 22     29                           Park     1    1    1
# 23     31                    Pizza Place     1    1    1
# 24     32                     Playground     1    1    1
# 25     33                      Roof Deck     1    1    1
# 26     41  Vegetarian / Vegan Restaurant     1    1    1
# 27     36                    Snack Place     1    1    1
# 28      0                 Animal Shelter     1    1    1
# 29     26                    Music Venue     1    1    1
# 30     23            Japanese Restaurant     1    1    1
# 31     19                          Hotel     1    1    1
# 32     18                  Grocery Store     1    1    1
# 33     17                   Gourmet Shop     1    1    1
# 34     16        Fruit & Vegetable Store     1    1    1
# 35     15              French Restaurant     1    1    1
# 36     14                     Food Stand     1    1    1
# 37     13            Dumpling Restaurant     1    1    1
# 38      8                   Cocktail Bar     1    1    1
# 39      6                 Cha Chaan Teng     1    1    1
# 40      5           Cantonese Restaurant     1    1    1
# 41      4                           Café     1    1    1
# 42      2                      Bike Shop     1    1    1
# 43     43                     Whisky Bar     1    1    1

# %% [markdown]
# Right now we have know that there are 44 unique categories of venues around "Deluxe Green Bo Restaurant". In them, the most category around "Deluxe Green Bo Restaurant" is "Chinese Restaurant", next is "Bakery" and "Dessert Shop" and so on. We want to find a similar place in Los Angeles.

# %% [markdown]
# Now let's create a grid of area candidates, equaly spaced, centered around city center. Our neighborhoods will be defined as circular areas with a radius of 300 meters, so our neighborhood centers will be 600 meters apart.
#
# To accurately calculate distances we need to create our grid of locations in Cartesian 2D coordinate system which allows us to calculate distances in meters (not in latitude/longitude degrees). Then we'll project those coordinates back to latitude/longitude degrees to be shown on Folium map. So let's create functions to convert between WGS84 spherical coordinate system (latitude/longitude degrees) and UTM Cartesian coordinate system (X/Y coordinates in  meters).

# %%
# !pip install shapely
import shapely.geometry

# !pip install pyproj
import pyproj

import math

def lonlat_to_xy(lon, lat):
    proj_latlon = pyproj.Proj(proj='latlong',datum='WGS84')
    proj_xy = pyproj.Proj(proj="utm", zone=33, datum='WGS84')
    xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
    return xy[0], xy[1]

def xy_to_lonlat(x, y):
    proj_latlon = pyproj.Proj(proj='latlong',datum='WGS84')
    proj_xy = pyproj.Proj(proj="utm", zone=33, datum='WGS84')
    lonlat = pyproj.transform(proj_xy, proj_latlon, x, y)
    return lonlat[0], lonlat[1]

def calc_xy_distance(x1, y1, x2, y2):
    dx = x2 - x1
    dy = y2 - y1
    return math.sqrt(dx*dx + dy*dy)

print('Coordinate transformation check')
print('-------------------------------')
print('Los Angeles longitude={}, latitude={}'.format(longitude_ca, latitude_ca))
x, y = lonlat_to_xy(longitude_ca, latitude_ca)
print('Los Angeles UTM X={}, Y={}'.format(x, y))
lo, la = xy_to_lonlat(x, y)
print('Los Angeles longitude={}, latitude={}'.format(lo, la))
# Out:
# Collecting shapely
#   Downloading Shapely-1.7.1-cp37-cp37m-manylinux1_x86_64.whl (1.0 MB)
#      |████████████████████████████████| 1.0 MB 10.7 MB/s eta 0:00:01
# Installing collected packages: shapely
# Successfully installed shapely-1.7.1
# Collecting pyproj
#   Downloading pyproj-3.0.0.post1-cp37-cp37m-manylinux2010_x86_64.whl (6.4 MB)
#      |████████████████████████████████| 6.4 MB 22.8 MB/s eta 0:00:01
# Requirement already satisfied: certifi in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from pyproj) (2020.6.20)
# Installing collected packages: pyproj
# Successfully installed pyproj-3.0.0.post1
# Coordinate transformation check
# -------------------------------
# Los Angeles longitude=-118.2427666, latitude=34.0536909
# Los Angeles UTM X=-3959962.027290968, Y=15049942.111933712
# Los Angeles longitude=-118.24276660000001, latitude=34.053690900000014
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/ipykernel/__main__.py:12: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/ipykernel/__main__.py:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1

# %% [markdown]
# Let's create a **hexagonal grid of cells**: we offset every other row, and adjust vertical row spacing so that **every cell center is equally distant from all it's neighbors**.

# %%
california_x, california_y = lonlat_to_xy(longitude_ca, latitude_ca) # City center in Cartesian coordinates

k = math.sqrt(3) / 2 # Vertical offset for hexagonal grid cells
x_min = california_x - 6000
x_step = 600
y_min = california_y - 6000 - (int(21/k)*k*600 - 12000)/2
y_step = 600 * k 

latitudes = []
longitudes = []
distances_from_center = []
xs = []
ys = []
for i in range(0, int(21/k)):
    y = y_min + i * y_step
    x_offset = 300 if i%2==0 else 0
    for j in range(0, 21):
        x = x_min + j * x_step + x_offset
        distance_from_center = calc_xy_distance(california_x, california_y, x, y)
        if (distance_from_center <= 6001):
            lon, lat = xy_to_lonlat(x, y)
            latitudes.append(lat)
            longitudes.append(lon)
            distances_from_center.append(distance_from_center)
            xs.append(x)
            ys.append(y)
# Out:
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/ipykernel/__main__.py:12: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/ipykernel/__main__.py:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/ipykernel/__main__.py:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/ipykernel/__main__.py:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/ipykernel/__main__.py:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/ipykernel/__main__.py:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/ipykernel/__main__.py:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/ipykernel/__main__.py:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/ipykernel/__main__.py:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/ipykernel/__main__.py:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/ipykernel/__main__.py:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/ipykernel/__main__.py:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/ipykernel/__main__.py:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/ipykernel/__main__.py:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/ipykernel/__main__.py:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/ipykernel/__main__.py:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/ipykernel/__main__.py:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/ipykernel/__main__.py:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/ipykernel/__main__.py:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/ipykernel/__main__.py:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/ipykernel/__main__.py:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/ipykernel/__main__.py:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/ipykernel/__main__.py:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/ipykernel/__main__.py:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/ipykernel/__main__.py:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/ipykernel/__main__.py:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/ipykernel/__main__.py:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/ipykernel/__main__.py:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/ipykernel/__main__.py:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/ipykernel/__main__.py:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/ipykernel/__main__.py:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/ipykernel/__main__.py:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/ipykernel/__main__.py:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/ipykernel/__main__.py:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/ipykernel/__main__.py:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/ipykernel/__main__.py:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/ipykernel/__main__.py:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/ipykernel/__main__.py:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/ipykernel/__main__.py:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/ipykernel/__main__.py:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/ipykernel/__main__.py:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/ipykernel/__main__.py:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/ipykernel/__main__.py:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/ipykernel/__main__.py:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/ipykernel/__main__.py:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/ipykernel/__main__.py:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/ipykernel/__main__.py:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/ipykernel/__main__.py:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/ipykernel/__main__.py:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/ipykernel/__main__.py:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/ipykernel/__main__.py:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/ipykernel/__main__.py:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/ipykernel/__main__.py:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/ipykernel/__main__.py:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/ipykernel/__main__.py:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/ipykernel/__main__.py:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/ipykernel/__main__.py:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/ipykernel/__main__.py:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/ipykernel/__main__.py:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/ipykernel/__main__.py:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/ipykernel/__main__.py:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/ipykernel/__main__.py:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/ipykernel/__main__.py:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/ipykernel/__main__.py:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/ipykernel/__main__.py:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/ipykernel/__main__.py:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/ipykernel/__main__.py:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/ipykernel/__main__.py:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/ipykernel/__main__.py:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/ipykernel/__main__.py:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/ipykernel/__main__.py:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/ipykernel/__main__.py:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/ipykernel/__main__.py:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/ipykernel/__main__.py:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/ipykernel/__main__.py:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/ipykernel/__main__.py:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/ipykernel/__main__.py:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/ipykernel/__main__.py:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/ipykernel/__main__.py:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/ipykernel/__main__.py:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/ipykernel/__main__.py:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/ipykernel/__main__.py:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/ipykernel/__main__.py:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/ipykernel/__main__.py:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/ipykernel/__main__.py:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/ipykernel/__main__.py:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/ipykernel/__main__.py:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/ipykernel/__main__.py:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/ipykernel/__main__.py:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/ipykernel/__main__.py:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/ipykernel/__main__.py:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/ipykernel/__main__.py:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/ipykernel/__main__.py:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/ipykernel/__main__.py:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/ipykernel/__main__.py:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/ipykernel/__main__.py:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/ipykernel/__main__.py:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/ipykernel/__main__.py:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/ipykernel/__main__.py:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/ipykernel/__main__.py:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/ipykernel/__main__.py:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/ipykernel/__main__.py:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/ipykernel/__main__.py:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/ipykernel/__main__.py:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/ipykernel/__main__.py:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/ipykernel/__main__.py:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/ipykernel/__main__.py:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/ipykernel/__main__.py:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/ipykernel/__main__.py:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/ipykernel/__main__.py:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/ipykernel/__main__.py:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/ipykernel/__main__.py:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/ipykernel/__main__.py:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/ipykernel/__main__.py:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/ipykernel/__main__.py:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/ipykernel/__main__.py:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/ipykernel/__main__.py:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/ipykernel/__main__.py:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/ipykernel/__main__.py:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/ipykernel/__main__.py:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/ipykernel/__main__.py:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/ipykernel/__main__.py:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/ipykernel/__main__.py:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/ipykernel/__main__.py:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/ipykernel/__main__.py:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/ipykernel/__main__.py:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/ipykernel/__main__.py:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/ipykernel/__main__.py:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/ipykernel/__main__.py:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/ipykernel/__main__.py:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/ipykernel/__main__.py:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/ipykernel/__main__.py:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/ipykernel/__main__.py:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/ipykernel/__main__.py:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/ipykernel/__main__.py:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/ipykernel/__main__.py:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/ipykernel/__main__.py:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/ipykernel/__main__.py:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/ipykernel/__main__.py:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/ipykernel/__main__.py:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/ipykernel/__main__.py:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/ipykernel/__main__.py:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/ipykernel/__main__.py:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/ipykernel/__main__.py:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/ipykernel/__main__.py:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/ipykernel/__main__.py:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/ipykernel/__main__.py:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/ipykernel/__main__.py:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/ipykernel/__main__.py:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/ipykernel/__main__.py:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/ipykernel/__main__.py:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/ipykernel/__main__.py:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/ipykernel/__main__.py:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/ipykernel/__main__.py:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/ipykernel/__main__.py:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/ipykernel/__main__.py:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/ipykernel/__main__.py:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/ipykernel/__main__.py:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/ipykernel/__main__.py:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/ipykernel/__main__.py:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/ipykernel/__main__.py:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/ipykernel/__main__.py:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/ipykernel/__main__.py:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/ipykernel/__main__.py:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/ipykernel/__main__.py:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/ipykernel/__main__.py:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/ipykernel/__main__.py:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/ipykernel/__main__.py:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/ipykernel/__main__.py:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/ipykernel/__main__.py:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/ipykernel/__main__.py:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/ipykernel/__main__.py:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/ipykernel/__main__.py:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/ipykernel/__main__.py:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/ipykernel/__main__.py:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/ipykernel/__main__.py:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/ipykernel/__main__.py:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/ipykernel/__main__.py:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/ipykernel/__main__.py:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/ipykernel/__main__.py:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/ipykernel/__main__.py:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/ipykernel/__main__.py:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/ipykernel/__main__.py:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/ipykernel/__main__.py:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/ipykernel/__main__.py:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/ipykernel/__main__.py:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/ipykernel/__main__.py:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/ipykernel/__main__.py:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/ipykernel/__main__.py:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/ipykernel/__main__.py:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/ipykernel/__main__.py:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/ipykernel/__main__.py:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/ipykernel/__main__.py:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/ipykernel/__main__.py:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/ipykernel/__main__.py:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/ipykernel/__main__.py:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/ipykernel/__main__.py:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/ipykernel/__main__.py:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/ipykernel/__main__.py:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/ipykernel/__main__.py:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/ipykernel/__main__.py:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/ipykernel/__main__.py:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/ipykernel/__main__.py:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/ipykernel/__main__.py:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/ipykernel/__main__.py:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/ipykernel/__main__.py:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/ipykernel/__main__.py:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/ipykernel/__main__.py:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/ipykernel/__main__.py:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
# ...
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/ipykernel/__main__.py:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/ipykernel/__main__.py:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/ipykernel/__main__.py:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/ipykernel/__main__.py:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/ipykernel/__main__.py:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/ipykernel/__main__.py:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/ipykernel/__main__.py:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/ipykernel/__main__.py:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/ipykernel/__main__.py:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/ipykernel/__main__.py:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/ipykernel/__main__.py:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/ipykernel/__main__.py:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/ipykernel/__main__.py:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/ipykernel/__main__.py:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/ipykernel/__main__.py:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/ipykernel/__main__.py:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/ipykernel/__main__.py:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/ipykernel/__main__.py:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/ipykernel/__main__.py:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/ipykernel/__main__.py:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/ipykernel/__main__.py:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/ipykernel/__main__.py:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/ipykernel/__main__.py:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/ipykernel/__main__.py:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/ipykernel/__main__.py:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/ipykernel/__main__.py:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/ipykernel/__main__.py:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/ipykernel/__main__.py:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/ipykernel/__main__.py:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/ipykernel/__main__.py:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/ipykernel/__main__.py:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/ipykernel/__main__.py:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/ipykernel/__main__.py:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/ipykernel/__main__.py:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/ipykernel/__main__.py:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/ipykernel/__main__.py:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/ipykernel/__main__.py:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/ipykernel/__main__.py:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/ipykernel/__main__.py:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/ipykernel/__main__.py:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/ipykernel/__main__.py:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/ipykernel/__main__.py:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/ipykernel/__main__.py:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/ipykernel/__main__.py:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/ipykernel/__main__.py:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/ipykernel/__main__.py:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/ipykernel/__main__.py:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/ipykernel/__main__.py:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/ipykernel/__main__.py:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/ipykernel/__main__.py:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/ipykernel/__main__.py:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/ipykernel/__main__.py:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/ipykernel/__main__.py:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/ipykernel/__main__.py:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/ipykernel/__main__.py:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/ipykernel/__main__.py:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/ipykernel/__main__.py:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/ipykernel/__main__.py:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/ipykernel/__main__.py:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/ipykernel/__main__.py:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/ipykernel/__main__.py:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/ipykernel/__main__.py:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/ipykernel/__main__.py:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/ipykernel/__main__.py:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/ipykernel/__main__.py:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/ipykernel/__main__.py:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/ipykernel/__main__.py:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/ipykernel/__main__.py:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/ipykernel/__main__.py:18: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1

# %%
print(len(latitudes), 'candidate neighborhood centers generated.')
# Out:
# 364 candidate neighborhood centers generated.

# %% [markdown]
# Let's visualize the data we have so far: city center location and candidate neighborhood centers:

# %%
map_california = folium.Map(location=[latitude_ca, longitude_ca], zoom_start=13)
folium.Marker([latitude_ca, longitude_ca], popup='California').add_to(map_california)
for lat, lon in zip(latitudes, longitudes):
    #folium.CircleMarker([lat, lon], radius=2, color='blue', fill=True, fill_color='blue', fill_opacity=1).add_to(map_berlin) 
    folium.Circle([lat, lon], radius=300, color='blue', fill=False).add_to(map_california)
    #folium.Marker([lat, lon]).add_to(map_berlin)
map_california
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# Let's now get approximate addresses of those locations.

# %%
def get_address(latitude, longitude):
    position = str(latitude) + ", " + str(longitude)
    geolocator = Nominatim(user_agent="ca_explorer")

    location = geolocator.reverse(position)
    return location.address
get_address(latitude_ca, longitude_ca)
# Out:
# 'Los Angeles City Hall, 200, North Spring Street, Civic Center, Downtown, Los Angeles, Los Angeles County, California, 90012, United States of America'

# %%
print('Obtaining location addresses: ', end='')
addresses = []
for lat, lon in zip(latitudes, longitudes):
    address = get_address(lat, lon)
    if address is None:
        address = 'NO ADDRESS'
    address = address.replace(', United States of America', '') # We don't need country part of address
    addresses.append(address)
    print(' .', end='')
print(' done.')
# Out:
# Obtaining location addresses:  . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . done.

# %%
addresses[150:170]
# Out:
# ['2570, Kent Street, Echo Park, Los Angeles, Los Angeles County, California, 90026',
#  '697, Parkman Avenue, Los Angeles, Los Angeles County, California, 90026',
#  'Holy Virgin Mary Russian Orthodox Cathedral, Micheltorena Street, Silver Lake, East Hollywood, Los Angeles, Los Angeles County, California, 90026-2106',
#  '3167, East 3rd Street, Boyle Heights, Los Angeles, Los Angeles County, California, 90063',
#  '2844, East 2nd Street, Boyle Heights, Los Angeles, Los Angeles County, California, 90033',
#  'Severa Synagogue, East 2nd Street, Boyle Heights, Los Angeles, Los Angeles County, California, 90033',
#  '2148, East 2nd Street, Brooklyn Heights, Boyle Heights, Los Angeles, Los Angeles County, California, 90033',
#  '1885, East 2nd Street, Brooklyn Heights, Boyle Heights, Los Angeles, Los Angeles County, California, 90033',
#  '199, Cancion Way, Pueblo Del Sol, Boyle Heights, Los Angeles, Los Angeles County, California, 90033',
#  '242, Mission Road, Boyle Heights, Los Angeles, Los Angeles County, California, 90033',
#  '718, Commercial Street, Arts District, Downtown, Los Angeles, Los Angeles County, California, 90012',
#  'Metropolitan Water District, Union Station Driveway, Downtown, Los Angeles, Los Angeles County, California, 90012',
#  'North Spring Street, El Pueblo, Downtown, Los Angeles, Los Angeles County, California, 90012',
#  'Ramón C. Cortines School of Visual and Performing Arts, North Hill Street, Civic Center, Downtown, Los Angeles, Los Angeles County, California, 90012',
#  'Da Vinci Apartments, Temple Street, Civic Center, Downtown, Los Angeles, Los Angeles County, California, 90012-2410',
#  '92, North Boylston Street, Echo Park, Los Angeles, Los Angeles County, California, 90012',
#  '345, Patton Street, Echo Park, Los Angeles, Los Angeles County, California, 90026',
#  '345, Dawson Street, Westlake, Los Angeles, Los Angeles County, California, 90026',
#  'Shell, Temple Street, Westlake, Los Angeles, Los Angeles County, California, 90026',
#  '428, Coronado Terrace, Westlake, Los Angeles, Los Angeles County, California, 90026']

# %% [markdown]
# Let's now place all this into a Pandas dataframe.

# %%
import pandas as pd

df_locations = pd.DataFrame({'Address': addresses,
                             'Latitude': latitudes,
                             'Longitude': longitudes,
                             'X': xs,
                             'Y': ys,
                             'Distance from center': distances_from_center})

df_locations.head(10)
# Out:
#                                              Address   Latitude   Longitude  \
# 0  3331, Thomas Street, Lincoln Heights, Los Ange...  34.082312 -118.204106
# 1  362, Avenue 33, Lincoln Heights, Los Angeles, ...  34.084526 -118.208553
# 2  Metro Park and Ride, Pasadena Avenue, Highland...  34.086739 -118.213000
# 3  453, Isabel Street, Cypress Park, Los Angeles,...  34.088952 -118.217448
# 4  3344, Pepper Avenue, Cypress Park, Los Angeles...  34.091165 -118.221896
# 5  2679, Loosmore Street, Cypress Park, Los Angel...  34.093378 -118.226344
# 6  2623, Arvia Street, Cypress Park, Los Angeles,...  34.095592 -118.230793
# 7  Abraham Lincoln High School, Lincoln Park Aven...  34.075789 -118.199741
# 8  2755, Alta Street, Lincoln Heights, Montecito ...  34.078002 -118.204187
# 9  472, Avenue 28, Lincoln Heights, Los Angeles, ...  34.080215 -118.208633
#
#               X             Y  Distance from center
# 0 -3.961762e+06  1.504423e+07           5992.495307
# 1 -3.961162e+06  1.504423e+07           5840.376700
# 2 -3.960562e+06  1.504423e+07           5747.173218
# 3 -3.959962e+06  1.504423e+07           5715.767665
# 4 -3.959362e+06  1.504423e+07           5747.173218
# 5 -3.958762e+06  1.504423e+07           5840.376700
# 6 -3.958162e+06  1.504423e+07           5992.495307
# 7 -3.962662e+06  1.504475e+07           5855.766389
# 8 -3.962062e+06  1.504475e+07           5604.462508
# 9 -3.961462e+06  1.504475e+07           5408.326913

# %% [markdown]
# We just select out first 10 categories with highest frequency since categories after the tenth only appear once or twice, and have little effect on the final result.

# %%
ten_categories = nearby_venues_grouped_rank.iloc[:10]['categories']
category_ids = ['4bf58dd8d48988d145941735', '4bf58dd8d48988d16a941735', '4bf58dd8d48988d1d0941735', '4bf58dd8d48988d1f5931735', '52e81612bcbc57f1066b7a0c', '4bf58dd8d48988d110951735', '4bf58dd8d48988d110941735', '52af3b593cf9994f4e043c00', '4bf58dd8d48988d1ed941735', '4bf58dd8d48988d1d1941735']
ten_categories
# Out:
# 0     Chinese Restaurant
# 1                 Bakery
# 2           Dessert Shop
# 3     Dim Sum Restaurant
# 4        Bubble Tea Shop
# 5     Salon / Barbershop
# 6     Italian Restaurant
# 7    Shanghai Restaurant
# 8                    Spa
# 9           Noodle House
# Name: categories, dtype: object

# %%
df_address = df_locations[df_locations.columns[:3]] 
df_address
# Out:
#                                                Address   Latitude   Longitude
# 0    3331, Thomas Street, Lincoln Heights, Los Ange...  34.082312 -118.204106
# 1    362, Avenue 33, Lincoln Heights, Los Angeles, ...  34.084526 -118.208553
# 2    Metro Park and Ride, Pasadena Avenue, Highland...  34.086739 -118.213000
# 3    453, Isabel Street, Cypress Park, Los Angeles,...  34.088952 -118.217448
# 4    3344, Pepper Avenue, Cypress Park, Los Angeles...  34.091165 -118.221896
# ..                                                 ...        ...         ...
# 359  753, East 33rd Street, Historic South-Central,...  34.016206 -118.263594
# 360  416, East 32nd Street, Historic South-Central,...  34.018413 -118.268042
# 361  129, West 32nd Street, Historic South-Central,...  34.020620 -118.272490
# 362  Harbor Freeway, Historic South-Central, Los An...  34.022828 -118.276939
# 363  Troy Hall, 3025, Royal Street, University Park...  34.025035 -118.281389
#
# [364 rows x 3 columns]

# %% [markdown]
# Let explore the first two categories for now since these two categories ("Chineses Restaurant" and "Bakery") are very impotant and with high frequency.
# By using Foursquare, we can search venues around the position with specific category. Then calculate the total number of venues which is also called frequency here.

# %%
for j in range(2):
    category_id = category_ids[j]
    category_name = ten_categories[j]
    category_frequency = []
    for i in range(df_locations.shape[0]):
        first_lat = df_locations.loc[i,'Latitude']
        first_lng = df_locations.loc[i,'Longitude']
        radius = 1000
        Limit = 50
        url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&categoryId={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, first_lat, first_lng, VERSION, category_id, radius, LIMIT)

        results = requests.get(url).json()
        # assign relevant part of JSON to venues
        venues = results['response']['venues']

        # tranform venues into a dataframe
        dataframe3 = json_normalize(venues)
        category_frequency.append(dataframe3.shape[0])
    df_address[category_name] = category_frequency
# Out:
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/ipykernel/__main__.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
df_address
# Out:
#                                                Address   Latitude   Longitude  \
# 0    3331, Thomas Street, Lincoln Heights, Los Ange...  34.082312 -118.204106
# 1    362, Avenue 33, Lincoln Heights, Los Angeles, ...  34.084526 -118.208553
# 2    Metro Park and Ride, Pasadena Avenue, Highland...  34.086739 -118.213000
# 3    453, Isabel Street, Cypress Park, Los Angeles,...  34.088952 -118.217448
# 4    3344, Pepper Avenue, Cypress Park, Los Angeles...  34.091165 -118.221896
# ..                                                 ...        ...         ...
# 359  753, East 33rd Street, Historic South-Central,...  34.016206 -118.263594
# 360  416, East 32nd Street, Historic South-Central,...  34.018413 -118.268042
# 361  129, West 32nd Street, Historic South-Central,...  34.020620 -118.272490
# 362  Harbor Freeway, Historic South-Central, Los An...  34.022828 -118.276939
# 363  Troy Hall, 3025, Royal Street, University Park...  34.025035 -118.281389
#
#      Chinese Restaurant  Bakery
# 0                     0       0
# 1                     0       0
# 2                     1       3
# 3                     1       2
# 4                     1       2
# ..                  ...     ...
# 359                   2       9
# 360                   3       8
# 361                   7       6
# 362                   7       7
# 363                   6       6
#
# [364 rows x 5 columns]

# %% [markdown]
# From the above dataframe, we can see that lots of places have few Chinese Restarants. We want similar neighborhoods, so let's filter address with number of Chinese Restaurants nearby in the range from 13 to 23 and number of Bakery nearby in the range from 4 to 10 since in NY, our restaurant has 18 Chinese Restaurants and 7 Bakeries nearby.

# %%
df_category_one = df_address[df_address['Chinese Restaurant'] > 13]
df_category_one = df_category_one[df_category_one['Chinese Restaurant'] < 23].reset_index(drop=True)
df_category_one.shape
# Out:
# (48, 5)

# %%
df_category_two = df_category_one[df_category_one['Bakery'] > 4]
df_category_two = df_category_two[df_category_two['Bakery'] < 10].reset_index(drop=True)
df_category_two
# Out:
#                                              Address   Latitude   Longitude  \
# 0  Solano Avenue, Elysian Park, Chinatown, Los An...  34.074032 -118.231186
# 1  North Main Street, Mission Junction LA, Chinat...  34.067509 -118.226816
# 2  Dodger Stadium, 1000, Vin Scully Avenue, Elysi...  34.074144 -118.240160
# 3  1480, North Boylston Street, Elysian Park, Los...  34.076355 -118.244610
# 4  431, Leroy Street, Mission Junction LA, Chinat...  34.063198 -118.226893
# 5  Vin Scully Avenue, Elysian Park, Los Angeles, ...  34.072043 -118.244686
#
#    Chinese Restaurant  Bakery
# 0                  14       8
# 1                  16       9
# 2                  14       5
# 3                  14       6
# 4                  19       9
# 5                  14       7

# %% [markdown]
# Now we only have 6 places left. That's good. Then we look at other categories and do the above process to calculate the number of venues with each category nearby.

# %%
for j in range(2,10):
    category_id = category_ids[j]
    category_name = ten_categories[j]
    category_frequency = []
    for i in range(df_category_two.shape[0]):
        first_lat = df_category_two.loc[i,'Latitude']
        first_lng = df_category_two.loc[i,'Longitude']
        radius = 1000
        Limit = 50
        url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&categoryId={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, first_lat, first_lng, VERSION, category_id, radius, LIMIT)

        results = requests.get(url).json()
        # assign relevant part of JSON to venues
        venues = results['response']['venues']

        # tranform venues into a dataframe
        dataframe3 = json_normalize(venues)
        category_frequency.append(dataframe3.shape[0])
    df_category_two[category_name] = category_frequency

# %%
df_category_two
# Out:
#                                              Address   Latitude   Longitude  \
# 0  Solano Avenue, Elysian Park, Chinatown, Los An...  34.074032 -118.231186
# 1  North Main Street, Mission Junction LA, Chinat...  34.067509 -118.226816
# 2  Dodger Stadium, 1000, Vin Scully Avenue, Elysi...  34.074144 -118.240160
# 3  1480, North Boylston Street, Elysian Park, Los...  34.076355 -118.244610
# 4  431, Leroy Street, Mission Junction LA, Chinat...  34.063198 -118.226893
# 5  Vin Scully Avenue, Elysian Park, Los Angeles, ...  34.072043 -118.244686
#
#    Chinese Restaurant  Bakery  Dessert Shop  Dim Sum Restaurant  \
# 0                  14       8             3                   3
# 1                  16       9             3                   3
# 2                  14       5             2                   3
# 3                  14       6             2                   3
# 4                  19       9             4                   4
# 5                  14       7             2                   3
#
#    Bubble Tea Shop  Salon / Barbershop  Italian Restaurant  \
# 0                0                   8                   2
# 1                1                  12                   0
# 2                0                  11                   2
# 3                0                  12                   2
# 4                1                  11                   0
# 5                0                  11                   3
#
#    Shanghai Restaurant  Spa  Noodle House
# 0                    0    1             1
# 1                    0    2             3
# 2                    0    1             0
# 3                    0    2             0
# 4                    0    4             3
# 5                    0    2             0

# %% [markdown]
# After getting above dataframe, we need to find how similar of each places with original restaurant's environment in NY. So we minus each number with original frequency and get the weight, and we will choose the optimal place according to this weight.

# %%
categories_freq_ny = nearby_venues_grouped_rank.iloc[:10]['name']

# %%
final_df = df_category_two[df_category_two.columns[:3]] 
weight = []
for i in range(6):
    value = 0
    for j in range(3,13):
        value += abs(df_category_two.iloc[i,j] - categories_freq_ny[j-3])
    weight.append(value)
final_df['weight'] = weight
# Out:
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/ipykernel/__main__.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
final_df
# Out:
#                                              Address   Latitude   Longitude  \
# 0  Solano Avenue, Elysian Park, Chinatown, Los An...  34.074032 -118.231186
# 1  North Main Street, Mission Junction LA, Chinat...  34.067509 -118.226816
# 2  Dodger Stadium, 1000, Vin Scully Avenue, Elysi...  34.074144 -118.240160
# 3  1480, North Boylston Street, Elysian Park, Los...  34.076355 -118.244610
# 4  431, Leroy Street, Mission Junction LA, Chinat...  34.063198 -118.226893
# 5  Vin Scully Avenue, Elysian Park, Los Angeles, ...  34.072043 -118.244686
#
#    weight
# 0      25
# 1      26
# 2      31
# 3      30
# 4      22
# 5      27

# %% [markdown]
# ## Results and Discussion <a name="results"></a>

# %% [markdown]
# From above we can see that, we got six places that satisfy our first two categories: "Chinese Restaurant" and "Bakery", which means that these six places have similar number of venues with those categories nearby. Combining other eight categories and calculating the weight, we find that the optimal place should be "431, Leroy Street, Mission Junction LA" with latitude 34.063198 and longitude -118.226893 since it has smallest number on weight so that it has most similar neighborhoods as restaurant in New York City. Thus, if "Deluxe Green Bo Restaurant" wants to open a chian restaurant in Los Angeles, then opening arond "431, Leroy Street, Mission Junction LA" should be a optimal choice.

# %% [markdown]
# ## Conclusion <a name="conclusion"></a>

# %% [markdown]
# Purpose of this project is to find a optimal location for a successful Chinese restaurant in New York to open a chain restaurant in Los Angeles. The first process for this project is to find a good restaurant to focus on, but if you have already know which brand you want to focus (not just restaurant, but also stores or any brands), then you can skip the first process. After deciding the restaurant to focus, we explored the neighborhoods of this restaurant, and then try to find a place in Los Angeles that has similar number of categories of neighborhoods. After analysis, we find that "431, Leroy Street, Mission Junction LA" is a optimal place for "Deluxe Green Bo Restaurant" to open a chain restaurant.
